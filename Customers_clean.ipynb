# %% [markdown]
# <a href="https://colab.research.google.com/github/shveta022-ks/Employee-exit-insights-dashboard/blob/main/Customers_clean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/customers_unclean.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4838/228541609.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("/content/customers_unclean.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.head(25)
# Out:
#     customer_id  customer_name                    email       city  \
# 0             1     Amit Patel     AMIT.PATEL@GMAIL.COM  Bangalore
# 1             2    Amit Kapoor    AMIT.KAPOOR@GMAIL.COM       pune
# 2             3    Rahul Verma    RAHUL.VERMA@GMAIL.COM     Jaipur
# 3             4    Sneha Kumar                      NaN      Delhi
# 4             5   Ishita Gupta   ishita.gupta@gmail.com     mumbai
# 5             6    Rohan Joshi    rohan.joshi@gmail.com  Ahmedabad
# 6             7  Vihaan Kapoor  vihaan.kapoor@gmail.com    Chennai
# 7             8     Aarav Iyer     aarav.iyer@gmail.com     Mumbai
# 8             9     Neha Kumar     neha.kumar@gmail.com      Delhi
# 9            10     Amit Kumar     amit.kumar@gmail.com     Mumbai
# 10           11    Rahul Singh    rahul.singh@gmail.com     Jaipur
# 11           12   Meera Sharma                      NaN    Chennai
# 12           13   Ananya Verma   ananya.verma@gmail.com  Ahmedabad
# ...

# %%
df.tail(10)
# Out:
#       customer_id  customer_name                    email       city  \
# 5190          682   Ananya Reddy   ananya.reddy@gmail.com    Kolkata
# 5191         3795   Ishita Kumar   ishita.kumar@gmail.com       Pune
# 5192         3945  Ananya Kapoor  ananya.kapoor@gmail.com     Mumbai
# 5193         4667    Aarav Gupta    aarav.gupta@gmail.com      Delhi
# 5194         2019    Sneha Gupta    sneha.gupta@gmail.com       Pune
# 5195         1097   Ishita Verma   ishita.verma@gmail.com    chennai
# 5196          830    Sneha Singh    sneha.singh@gmail.com    Chennai
# 5197         2806     Neha Singh     neha.singh@gmail.com     Mumbai
# 5198         3830    Neha Sharma    neha.sharma@gmail.com     mumbai
# 5199         4382    Aarav Gupta                      NaN  Bangalore
#
#             state
# 5190        Delhi
# 5191    Karnataka
# 5192  West Bengal
# 5193  West Bengal
# 5194    Karnataka
# 5195      Gujarat
# 5196  Maharashtra
# 5197      Gujarat
# 5198    Rajasthan
# ...

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4838/3089318408.py in <cell line: 0>()
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.shape
# Out:
# (5200, 5)

# %%
df.columns
# Out:
# Index(['customer_id', 'customer_name', 'email', 'city', 'state'], dtype='object')

# %%
df.describe()
# Out:
#        customer_id
# count  5200.000000
# mean   2497.037115
# std    1445.273612
# min       1.000000
# 25%    1242.750000
# 50%    2499.500000
# 75%    3747.250000
# max    5000.000000

# %%
df.isnull().sum()
# Out:
# customer_id      0
# customer_name    0
# email            0
# city             0
# state            0
# dtype: int64

# %%
df['email'] = df['email'].fillna('unknown')

# %%
df.head(25)
# Out:
#     customer_id  customer_name                    email       city  \
# 0             1     Amit Patel     AMIT.PATEL@GMAIL.COM  Bangalore
# 1             2    Amit Kapoor    AMIT.KAPOOR@GMAIL.COM       pune
# 2             3    Rahul Verma    RAHUL.VERMA@GMAIL.COM     Jaipur
# 3             4    Sneha Kumar                  unknown      Delhi
# 4             5   Ishita Gupta   ishita.gupta@gmail.com     mumbai
# 5             6    Rohan Joshi    rohan.joshi@gmail.com  Ahmedabad
# 6             7  Vihaan Kapoor  vihaan.kapoor@gmail.com    Chennai
# 7             8     Aarav Iyer     aarav.iyer@gmail.com     Mumbai
# 8             9     Neha Kumar     neha.kumar@gmail.com      Delhi
# 9            10     Amit Kumar     amit.kumar@gmail.com     Mumbai
# 10           11    Rahul Singh    rahul.singh@gmail.com     Jaipur
# 11           12   Meera Sharma                  unknown    Chennai
# 12           13   Ananya Verma   ananya.verma@gmail.com  Ahmedabad
# ...

# %%
df['city'] = df['city'].str.title()
df['state'] = df['state'].str.title()

# %%
df.head(25)
# Out:
#     customer_id  customer_name                    email       city  \
# 0             1     Amit Patel     AMIT.PATEL@GMAIL.COM  Bangalore
# 1             2    Amit Kapoor    AMIT.KAPOOR@GMAIL.COM       Pune
# 2             3    Rahul Verma    RAHUL.VERMA@GMAIL.COM     Jaipur
# 3             4    Sneha Kumar                  unknown      Delhi
# 4             5   Ishita Gupta   ishita.gupta@gmail.com     Mumbai
# 5             6    Rohan Joshi    rohan.joshi@gmail.com  Ahmedabad
# 6             7  Vihaan Kapoor  vihaan.kapoor@gmail.com    Chennai
# 7             8     Aarav Iyer     aarav.iyer@gmail.com     Mumbai
# 8             9     Neha Kumar     neha.kumar@gmail.com      Delhi
# 9            10     Amit Kumar     amit.kumar@gmail.com     Mumbai
# 10           11    Rahul Singh    rahul.singh@gmail.com     Jaipur
# 11           12   Meera Sharma                  unknown    Chennai
# 12           13   Ananya Verma   ananya.verma@gmail.com  Ahmedabad
# ...

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %% [markdown]
# check duplicates.

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head(110)
# Out:
#      customer_id  customer_name                    email       city  \
# 0              1     Amit Patel     AMIT.PATEL@GMAIL.COM  Bangalore
# 1              2    Amit Kapoor    AMIT.KAPOOR@GMAIL.COM       Pune
# 2              3    Rahul Verma    RAHUL.VERMA@GMAIL.COM     Jaipur
# 3              4    Sneha Kumar                  unknown      Delhi
# 4              5   Ishita Gupta   ishita.gupta@gmail.com     Mumbai
# ..           ...            ...                      ...        ...
# 105          106  Ishita Chopra  ishita.chopra@gmail.com  Ahmedabad
# 106          107   Aditya Gupta   aditya.gupta@gmail.com     Mumbai
# 107          108    Rahul Reddy    rahul.reddy@gmail.com  Bangalore
# 108          109   Priya Chopra   priya.chopra@gmail.com    Kolkata
# 109          110    Sneha Patel    sneha.patel@gmail.com  Bangalore
#
#            state
# 0      Karnataka
# 1     Tamil Nadu
# 2    West Bengal
# 3      Rajasthan
# 4      Karnataka
# ..           ...
# 105  Maharashtra
# ...

# %%
df.loc['city'] = df['city']

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ba96d01b-aae9-41be-9f89-251e5fd67bd6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba96d01b-aae9-41be-9f89-251e5fd67bd6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("/content/customers_unclean.csv")

# %%
df.head(25)
# Out:
#     customer_id  customer_name                    email       city  \
# 0           1.0     Amit Patel     AMIT.PATEL@GMAIL.COM  Bangalore
# 1           2.0    Amit Kapoor    AMIT.KAPOOR@GMAIL.COM       pune
# 2           3.0    Rahul Verma    RAHUL.VERMA@GMAIL.COM     Jaipur
# 3           4.0    Sneha Kumar                      NaN      Delhi
# 4           5.0   Ishita Gupta   ishita.gupta@gmail.com     mumbai
# 5           6.0    Rohan Joshi    rohan.joshi@gmail.com  Ahmedabad
# 6           7.0  Vihaan Kapoor  vihaan.kapoor@gmail.com    Chennai
# 7           8.0     Aarav Iyer     aarav.iyer@gmail.com     Mumbai
# 8           9.0     Neha Kumar     neha.kumar@gmail.com      Delhi
# 9          10.0     Amit Kumar     amit.kumar@gmail.com     Mumbai
# 10         11.0    Rahul Singh    rahul.singh@gmail.com     Jaipur
# 11         12.0   Meera Sharma                      NaN    Chennai
# 12         13.0   Ananya Verma   ananya.verma@gmail.com  Ahmedabad
# ...

# %%
df = pd.read_csv("/content/orders_unclean.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     25000 non-null  int64
#  1   customer_id  25000 non-null  int64
#  2   order_date   25000 non-null  object
#  3   ship_mode    25000 non-null  object
#  4   region       25000 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 976.7+ KB

# %%
df.head(25)
# Out:
#     order_id  customer_id  order_date       ship_mode   region
# 0          1         1127  2019-02-25     First Class     West
# 1          2         4005  2019-01-24     First Class     East
# 2          3         4777  2021-04-03    Second Class  Central
# 3          4         2954  2019-03-09    Second Class     East
# 4          5         2534  2019-06-04  Standard Class     East
# 5          6         3473  2022-08-17        Same Day     East
# 6          7         1640  2021-01-18  Standard Class     East
# 7          8         3477  2020-10-09     First Class  Central
# 8          9          891  2021-04-18  Standard Class    South
# 9         10         1161  2020-07-07        Same Day  Central
# 10        11         2255  2021-12-29  Standard Class    South
# 11        12         3593  2020-03-05  Standard Class     East
# 12        13         4342  2021-04-02    Second Class    South
# 13        14         4374  2019-05-03     First Class    South
# ...

# %%
df.iloc[0:25,0:5]
# Out:
#     order_id  customer_id  order_date       ship_mode   region
# 0          1         1127  2019-02-25     First Class     West
# 1          2         4005  2019-01-24     First Class     East
# 2          3         4777  2021-04-03    Second Class  Central
# 3          4         2954  2019-03-09    Second Class     East
# 4          5         2534  2019-06-04  Standard Class     East
# 5          6         3473  2022-08-17        Same Day     East
# 6          7         1640  2021-01-18  Standard Class     East
# 7          8         3477  2020-10-09     First Class  Central
# 8          9          891  2021-04-18  Standard Class    South
# 9         10         1161  2020-07-07        Same Day  Central
# 10        11         2255  2021-12-29  Standard Class    South
# 11        12         3593  2020-03-05  Standard Class     East
# 12        13         4342  2021-04-02    Second Class    South
# 13        14         4374  2019-05-03     First Class    South
# ...
